# %% [markdown]
# # 0 - Setup

# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient
from tidytext import unnest_tokens

import os
import gn_modules.store as gn_store
import gn_modules.secure_dotenv as gn_dotenv

gn_dotenv.load_dotenv_secure()

# %%
NAME_FILE = 'prenoms_clean.csv'

# %% [markdown]
# # 1 - get data from the db

# %%
def read_mongo(query={}, no_id=True):
    """ Read from Mongo and Store into DataFrame """

    cursor = gn_store.connect_db().find(query)

    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor))

    # Delete the _id
    if no_id:
        del df['_id']

    return df

# %%
# Every article after the 1st of january 2021
df = read_mongo(query= { 'date' : { '$gte' : '2021-02-01'}})
df.head()
# Out:
#                        link        date  \
# 0        http://laroche.fr/  2021-02-16
# 1    http://www.gillet.net/  2021-02-01
# 2         http://faure.org/  2021-02-07
# 3  https://www.grondin.com/  2021-02-05
# 4  https://www.sauvage.com/  2021-02-07
#
#                                            title  \
# 0  Souhaiter planche mort davantage prince part.
# 1               Île oeuvre oui fortune préférer.
# 2           Doute autre est peine disposer sous.
# 3                  Malgré rouge devenir société.
# 4       Remplir témoin sujet mode haïr proposer.
#
#                                                 text              source  \
# 0  Cercle acte port hasard. Professeur un clef po...  [rejeter, instant]
# 1  Chaque contenter simplement temps eh premier p...        [serrer, as]
# 2  Or premier tromper choix regard. Voisin assure...    [haïr, mensonge]
# 3  Conversation toute chute moyen sou pleurer con...  [compte, rassurer]
# 4  Promener voile nez fauteuil étranger éclat sub...        [abri, tout]
#
#                                              authors     categories  \
# 0                      [Monique Voisin, Lucy Daniel]        Culture
# 1  [Luc-Théophile Bouchet, Élodie Boulanger-Duhamel]  International
# 2                 [Thierry Lenoir, Marthe Le Renard]  International
# 3       [Bernard Richard, Victoire Samson du Muller]  International
# 4     [Tristan de la Ramos, Margaret Le Gall-Benoit]  International
#
#   sub_categories                        keywords  word_count  \
# 0        cerveau  [sauter, apprendre, président]        4129
# 1            foi  [rejoindre, chien, silencieux]        3079
# 2          règle      [impossible, robe, action]        4105
# 3          armée          [mode, vieil, absence]        3578
# 4         détail      [sourd, prouver, demander]        3498
#
#                               gender_count  masculinity_rate  \
# 0  {'male': 15, 'female': 8, 'unknown': 4}          0.924862
# 1  {'male': 15, 'female': 9, 'unknown': 4}          0.435256
# 2  {'male': 13, 'female': 6, 'unknown': 2}          0.661014
# 3  {'male': 14, 'female': 5, 'unknown': 2}          0.346604
# 4  {'male': 13, 'female': 9, 'unknown': 4}          0.237862
#
#                                                names
# 0  [{'name': 'Paul Ollivier', 'gender': 'male', '...
# 1  [{'name': 'Jacques Marchand', 'gender': 'male'...
# 2  [{'name': 'Victor Tessier', 'gender': 'male', ...
# 3  [{'name': 'Victor Fernandez', 'gender': 'male'...
# 4  [{'name': 'Charles Riou', 'gender': 'male', 'o...

# %% [markdown]
# # 2 - Get the names df

# %%
names_df = pd.read_csv(NAME_FILE, sep=';')
names_df = names_df.rename(columns={'preusuel': 'word'})
names_df.head()
# Out:
#      word  sexratio_prenom    n sexe_prenom
# 0   aadam              1.0   24       Homme
# 1   aadel              1.0   55       Homme
# 2   aadil              1.0  177       Homme
# 3  aakash              1.0   25       Homme
# 4   aalia              0.0   26       Femme

# %% [markdown]
# # 3 - Compute masculinity score

# %%
txt_tokens = unnest_tokens(df[['text']], 'word', 'text')
txt_tokens['id'] = txt_tokens.index
txt_tokens
# Out:
#             word    id
# 0         cercle     0
# 0           acte     0
# 0           port     0
# 0         hasard     0
# 0     professeur     0
# ...          ...   ...
# 4679   rencontre  4679
# 4679   souhaiter  4679
# 4679   printemps  4679
# 4679       comme  4679
# 4679   réflexion  4679
#
# [3183030 rows x 2 columns]

# %%
txt_tokens_with_name = pd.merge(txt_tokens, names_df, how='left')
txt_tokens_with_name
# Out:
#                word    id  sexratio_prenom   n sexe_prenom
# 0            cercle     0              NaN NaN         NaN
# 1              acte     0              NaN NaN         NaN
# 2              port     0              NaN NaN         NaN
# 3            hasard     0              NaN NaN         NaN
# 4        professeur     0              NaN NaN         NaN
# ...             ...   ...              ...  ..         ...
# 3183025   rencontre  4679              NaN NaN         NaN
# 3183026   souhaiter  4679              NaN NaN         NaN
# 3183027   printemps  4679              NaN NaN         NaN
# 3183028       comme  4679              NaN NaN         NaN
# 3183029   réflexion  4679              NaN NaN         NaN
#
# [3183030 rows x 5 columns]

# %%
matches = txt_tokens_with_name.dropna()
matches = matches.drop(columns = ['n'])
matches
# Out:
#              word    id  sexratio_prenom sexe_prenom
# 707      françois     1         0.999358       Homme
# 1269       claire     1         0.001380       Femme
# 1425       claire     2         0.001380       Femme
# 2625     françois     3         0.999358       Homme
# 2858       pierre     4         0.998965       Homme
# ...           ...   ...              ...         ...
# 3180952    pierre  4676         0.998965       Homme
# 3181231    pierre  4677         0.998965       Homme
# 3182025  françois  4678         0.999358       Homme
# 3182373    claire  4679         0.001380       Femme
# 3182572    claire  4679         0.001380       Femme
#
# [6496 rows x 4 columns]

# %%
m_rate = txt_tokens_with_name.groupby('id')['sexratio_prenom'].mean()
m_rate
# Out:
# id
# 0            NaN
# 1       0.500369
# 2       0.001380
# 3       0.999358
# 4       0.500172
#           ...
# 4675    0.001380
# 4676    0.999161
# 4677    0.998965
# 4678    0.999358
# 4679    0.001380
# Name: sexratio_prenom, Length: 4680, dtype: float64

# %%
df['masculinity_rate'] = m_rate
df.head()
# Out:
#                        link        date  \
# 0        http://laroche.fr/  2021-02-16
# 1    http://www.gillet.net/  2021-02-01
# 2         http://faure.org/  2021-02-07
# 3  https://www.grondin.com/  2021-02-05
# 4  https://www.sauvage.com/  2021-02-07
#
#                                            title  \
# 0  Souhaiter planche mort davantage prince part.
# 1               Île oeuvre oui fortune préférer.
# 2           Doute autre est peine disposer sous.
# 3                  Malgré rouge devenir société.
# 4       Remplir témoin sujet mode haïr proposer.
#
#                                                 text              source  \
# 0  Cercle acte port hasard. Professeur un clef po...  [rejeter, instant]
# 1  Chaque contenter simplement temps eh premier p...        [serrer, as]
# 2  Or premier tromper choix regard. Voisin assure...    [haïr, mensonge]
# 3  Conversation toute chute moyen sou pleurer con...  [compte, rassurer]
# 4  Promener voile nez fauteuil étranger éclat sub...        [abri, tout]
#
#                                              authors     categories  \
# 0                      [Monique Voisin, Lucy Daniel]        Culture
# 1  [Luc-Théophile Bouchet, Élodie Boulanger-Duhamel]  International
# 2                 [Thierry Lenoir, Marthe Le Renard]  International
# 3       [Bernard Richard, Victoire Samson du Muller]  International
# 4     [Tristan de la Ramos, Margaret Le Gall-Benoit]  International
#
#   sub_categories                        keywords  word_count  \
# 0        cerveau  [sauter, apprendre, président]        4129
# 1            foi  [rejoindre, chien, silencieux]        3079
# 2          règle      [impossible, robe, action]        4105
# 3          armée          [mode, vieil, absence]        3578
# 4         détail      [sourd, prouver, demander]        3498
#
#                               gender_count  masculinity_rate  \
# 0  {'male': 15, 'female': 8, 'unknown': 4}               NaN
# 1  {'male': 15, 'female': 9, 'unknown': 4}          0.500369
# 2  {'male': 13, 'female': 6, 'unknown': 2}          0.001380
# 3  {'male': 14, 'female': 5, 'unknown': 2}          0.999358
# 4  {'male': 13, 'female': 9, 'unknown': 4}          0.500172
#
#                                                names
# 0  [{'name': 'Paul Ollivier', 'gender': 'male', '...
# 1  [{'name': 'Jacques Marchand', 'gender': 'male'...
# 2  [{'name': 'Victor Tessier', 'gender': 'male', ...
# 3  [{'name': 'Victor Fernandez', 'gender': 'male'...
# 4  [{'name': 'Charles Riou', 'gender': 'male', 'o...

# %% [markdown]
# # 4 - Retrieve extracted names (wip)

# %%
names = matches.groupby(['id', 'word'])['word'].count()

# %%
names.reset_index(col_fill = 'count')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-394c28c347dd> in <module>
# ----> 1 names.reset_index(col_fill = 'count')
#
# TypeError: reset_index() got an unexpected keyword argument 'col_fill'
